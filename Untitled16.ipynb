# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv("customer_churn_dataset-testing-master.csv")

print(df.head())
print("\nShape of dataset:", df.shape)
print("\nColumn Names:", df.columns.tolist())
# Out:
#    CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0           1   22  Female      25               14              4
# 1           2   41  Female      28               28              7
# 2           3   47    Male      27               10              2
# 3           4   35    Male       9               12              5
# 4           5   53  Female      58               24              9
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0             27             Basic         Monthly          598
# 1             13          Standard         Monthly          584
# 2             29           Premium          Annual          757
# 3             17           Premium       Quarterly          232
# 4              2          Standard          Annual          533
#
#    Last Interaction  Churn
# 0                 9      1
# 1                20      0
# 2                21      0
# 3                18      0
# 4                18      0
#
# Shape of dataset: (64374, 12)
#
# Column Names: ['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency', 'Support Calls', 'Payment Delay', 'Subscription Type', 'Contract Length', 'Total Spend', 'Last Interaction', 'Churn']

# %%
print("\nMissing Values:\n", df.isnull().sum())
print("\nDuplicate Rows:", df.duplicated().sum())
print("\nData Types:\n", df.dtypes)
#data cleaning
# Out:
# Missing Values:
#  CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# Usage Frequency      0
# Support Calls        0
# Payment Delay        0
# Subscription Type    0
# Contract Length      0
# Total Spend          0
# Last Interaction     0
# Churn                0
# dtype: int64
#
# Duplicate Rows: 0
#
# Data Types:
#  CustomerID            int64
# Age                   int64
# Gender               object
# Tenure                int64
# Usage Frequency       int64
# Support Calls         int64
# Payment Delay         int64
# Subscription Type    object
# Contract Length      object
# Total Spend           int64
# Last Interaction      int64
# Churn                 int64
# dtype: object

# %%
print("\nSummary Statistics:\n", df.describe())

print("\nChurn Value Counts:")
print(df["Churn"].value_counts())
# Out:
# Summary Statistics:
#           CustomerID           Age        Tenure  Usage Frequency  \
# count  64374.000000  64374.000000  64374.000000     64374.000000
# mean   32187.500000     41.970982     31.994827        15.080234
# std    18583.317451     13.924911     17.098234         8.816470
# min        1.000000     18.000000      1.000000         1.000000
# 25%    16094.250000     30.000000     18.000000         7.000000
# 50%    32187.500000     42.000000     33.000000        15.000000
# 75%    48280.750000     54.000000     47.000000        23.000000
# max    64374.000000     65.000000     60.000000        30.000000
#
#        Support Calls  Payment Delay   Total Spend  Last Interaction  \
# count   64374.000000   64374.000000  64374.000000      64374.000000
# mean        5.400690      17.133952    541.023379         15.498850
# std         3.114005       8.852211    260.874809          8.638436
# min         0.000000       0.000000    100.000000          1.000000
# 25%         3.000000      10.000000    313.000000          8.000000
# 50%         6.000000      19.000000    534.000000         15.000000
# 75%         8.000000      25.000000    768.000000         23.000000
# max        10.000000      30.000000   1000.000000         30.000000
#
#               Churn
# count  64374.000000
# mean       0.473685
# std        0.499311
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
#
# Churn Value Counts:
# Churn
# 0    33881
# 1    30493
# Name: count, dtype: int64

# %%
numeric_cols = ["Age","Tenure","Usage Frequency","Support Calls",
                "Payment Delay","Total Spend"]

for col in numeric_cols:
    plt.figure()
    plt.hist(df[col].dropna(), bins=20)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
for col in numeric_cols:
    plt.figure()
    df.groupby("Churn")[col].mean().plot(kind="bar")
    plt.title(f"{col} vs Churn")
    plt.ylabel("Average Value")
    plt.show()

# %%
for col in numeric_cols:
    plt.figure()
    df.groupby("Churn")[col].mean().plot(kind="bar")
    plt.title(f"{col} vs Churn")
    plt.ylabel("Average Value")
    plt.show()

# %%
corr = df[numeric_cols].corr()
print("\nCorrelation Matrix:\n", corr)
# Out:
# Correlation Matrix:
#                        Age    Tenure  Usage Frequency  Support Calls  \
# Age              1.000000 -0.007763        -0.038331       0.005014
# Tenure          -0.007763  1.000000         0.023485       0.060065
# Usage Frequency -0.038331  0.023485         1.000000      -0.014072
# Support Calls    0.005014  0.060065        -0.014072       1.000000
# Payment Delay   -0.016132  0.055963         0.031132       0.064298
# Total Spend      0.006490  0.009474         0.001527       0.021750
#
#                  Payment Delay  Total Spend
# Age                  -0.016132     0.006490
# Tenure                0.055963     0.009474
# Usage Frequency       0.031132     0.001527
# Support Calls         0.064298     0.021750
# Payment Delay         1.000000    -0.031119
# Total Spend          -0.031119     1.000000
